# %%
#@title Gemma 3-4B-it installation

# IMPORTANT: set env vars BEFORE importing torch_xla/torch for them to take effect
import os
os.environ.setdefault("PJRT_DEVICE", "TPU")
os.environ.setdefault("XLA_USE_BF16", "1")
# avoid aggressive preallocation of HBM on XLA
os.environ.setdefault("XLA_PYTHON_CLIENT_PREALLOCATE", "false")
os.environ.setdefault("XLA_PYTHON_CLIENT_MEM_FRACTION", "0.99")

import gc
import warnings
warnings.filterwarnings("ignore", message=".*deprecated.*will be removed in Transformers v5.*")

import torch
import torch_xla.core.xla_model as xm
from transformers import AutoModelForCausalLM, AutoTokenizer, AutoConfig

model_id = "google/gemma-3-4b-it"

print("XLA devices:", xm.get_xla_supported_devices())
device = xm.xla_device()
print("Using device:", device)

# ---------------------------
# Load tokenizer & model
# ---------------------------
tokenizer = AutoTokenizer.from_pretrained(model_id)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"

print("Loading model (this can take a while)...")
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    dtype=torch.bfloat16,
    low_cpu_mem_usage=True,
    device_map="cpu",
)

# Safety: disable HF caching logic that triggers cache_utils.update() slicing on XLA
model.config.use_cache = False
try:
    model.generation_config.use_cache = False
except Exception:
    pass

# Make sliding_window safe (1 is conservative)
try:
    model.config.sliding_window = 1
    model.generation_config.sliding_window = 1
except Exception:
    pass

# eager attention implementation if available for TPU if available
try:
    model.config.attn_implementation = "eager"
except Exception:
    pass

# Move model to XLA device and eval
model.to(device)
model.eval()

# ---------------------------
# Quick sanity checks
# ---------------------------
first_param = next(model.parameters())
print("Param device:", first_param.device)
print("Param dtype:", first_param.dtype)
print("Model num params (approx):", sum(p.numel() for p in model.parameters()))

# Prepare tiny input
prompt = "Hello"
inputs = tokenizer(prompt, return_tensors="pt")
print("Input ids shape (cpu):", inputs["input_ids"].shape)

# Move inputs to device
inputs = {k: v.to(device) for k, v in inputs.items()}
print("Input device after move:", inputs["input_ids"].device)

# 1) Quick forward to check forward pass (explicitly disable cache)
try:
    print("Running single forward (no generate), passing use_cache=False ...")
    with torch.no_grad():
        out = model(**inputs, use_cache=False)
    xm.mark_step()
    logits = out.logits if hasattr(out, "logits") else out[0]
    print("Forward succeeded. Logits shape:", logits.shape)
except Exception as e:
    print("Forward FAILED:", repr(e))
    # try to free memory and re-raise to surface the stacktrace
    gc.collect()
    xm.mark_step()
    raise

# 2) Minimal generate for test (use_cache=False)
try:
    print("Starting minimal generate with use_cache=False, max_new_tokens=8 ...")
    with torch.no_grad():
        outids = model.generate(
            **inputs,
            max_new_tokens=8,
            do_sample=False,
            num_beams=1,
            use_cache=False,
            pad_token_id=tokenizer.pad_token_id,
            eos_token_id=tokenizer.eos_token_id,
            return_dict_in_generate=False,
        )
    xm.mark_step()
    print("Decode:", tokenizer.decode(outids[0], skip_special_tokens=True))
except Exception as e:
    print("Generate FAILED or blocked:", repr(e))
    gc.collect()
    xm.mark_step()
    raise

print("Done small test.")
# Out:
# /usr/local/lib/python3.12/dist-packages/torch_xla/experimental/gru.py:113: SyntaxWarning: invalid escape sequence '\_'
#   * **h_n**: tensor of shape :math:`(D * \text{num\_layers}, H_{out})` or
# XLA devices: ['xla:0']
# Using device: xla:0
# /tmp/ipython-input-3561029804.py:20: DeprecationWarning: Use torch_xla.device instead
#   device = xm.xla_device()
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Loading model (this can take a while)...
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/jax/_src/cloud_tpu_init.py:82: UserWarning: Transparent hugepages are not enabled. TPU runtime startup and shutdown time should be significantly improved on TPU v5e and newer. If not already set, you may need to enable transparent hugepages in your VM image (sudo sh -c "echo always > /sys/kernel/mm/transparent_hugepage/enabled")
#   warnings.warn(
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.64G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Param device: xla:0
# Param dtype: torch.bfloat16
# Model num params (approx): 4971331952
# Input ids shape (cpu): torch.Size([1, 2])
# Input device after move: xla:0
# Running single forward (no generate), passing use_cache=False ...
# /tmp/ipython-input-3561029804.py:85: DeprecationWarning: Use torch_xla.sync instead
#   xm.mark_step()
# The following generation flags are not valid and may be ignored: ['top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Forward succeeded. Logits shape: torch.Size([1, 2, 262208])
# Starting minimal generate with use_cache=False, max_new_tokens=8 ...
# /tmp/ipython-input-3561029804.py:109: DeprecationWarning: Use torch_xla.sync instead
#   xm.mark_step()
# Decode: Hello 2024!
#
# I
# Done small test.

# %%
#@title Gemma 3-4B-it generation speed on TPU v5e 1

import os, time, gc, statistics
import torch
import torch_xla.core.xla_model as xm
from transformers import AutoModelForCausalLM, AutoTokenizer

# ---------- Config ----------
MODEL_ID = "google/gemma-3-4b-it"   # used only if model/tokenizer/device are not present
REPEATS = 2                         # repeat measurements and report average+std
WARMUP_NEW_TOKENS = 1               # short warm-up generation
USE_CACHE_FOR_MEASUREMENT = False   # default False to avoid XLA cache slicing issues
VERBOSE = True
# ----------------------------

# --- New: explicit prompts requested by the user
PROMPTS = [
    "Hello, how are you",
    "Hello. What do you think about Greek philosophy?"
]

# Ensure model/tokenizer/device available (use existing if in globals)
globals_ref = globals()
if "model" in globals_ref and "tokenizer" in globals_ref and "device" in globals_ref:
    model = globals_ref["model"]
    tokenizer = globals_ref["tokenizer"]
    device = globals_ref["device"]
    if VERBOSE:
        print("Using existing model/tokenizer/device from session.")
else:
    if VERBOSE:
        print("Loading model/tokenizer (this will take time)...")
    # ensure XLA envs set externally earlier in session; just load
    tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token
    tokenizer.padding_side = "left"
    model = AutoModelForCausalLM.from_pretrained(
        MODEL_ID,
        dtype=torch.bfloat16,
        low_cpu_mem_usage=True,
        device_map="cpu",
    )
    # Make safe for XLA
    model.config.use_cache = False
    try:
        model.generation_config.use_cache = False
    except Exception:
        pass
    try:
        model.config.sliding_window = 1
        model.generation_config.sliding_window = 1
    except Exception:
        pass
    device = xm.xla_device()
    model.to(device)
    model.eval()

# Safety: ensure model on device
first_param = next(model.parameters())
if first_param.device != device:
    model.to(device)

print("Model device:", next(model.parameters()).device, "dtype:", next(model.parameters()).dtype)

results = []

for prompt in PROMPTS:
    # tokenize to find actual prompt token length
    input_enc = tokenizer(prompt, return_tensors="pt")
    input_ids = input_enc["input_ids"]
    actual_prompt_tokens = int(input_ids.shape[-1])

    if VERBOSE:
        print(f"\n=== Experiment: prompt (text)='{prompt}'")
        print(f"    actual prompt tokens={actual_prompt_tokens}")

    # prepare inputs on device
    inputs = {k: v.to(device) for k, v in input_enc.items()}
    input_len = int(inputs["input_ids"].shape[-1])

    # warm-up (short generation) to reduce first-call compilation overhead
    try:
        if VERBOSE:
            print("Warm-up generate (short)...")
        with torch.no_grad():
            _ = model.generate(
                **inputs,
                max_new_tokens=WARMUP_NEW_TOKENS,
                do_sample=False,
                num_beams=1,
                use_cache=False,   # keep warm-up safe
                pad_token_id=tokenizer.pad_token_id,
                eos_token_id=tokenizer.eos_token_id,
                return_dict_in_generate=False,
            )
        xm.mark_step()
    except Exception as e:
        print("Warm-up failed:", e)
        # continue — we will still attempt timed runs

    # measurement runs
    gen_new_tokens = actual_prompt_tokens  # mirror original behavior: generate same number as input tokens
    times = []
    for rep in range(REPEATS):
        gc.collect()
        torch.cuda.empty_cache() if torch.cuda.is_available() else None
        t0 = time.perf_counter()
        try:
            with torch.no_grad():
                out = model.generate(
                    **inputs,
                    max_new_tokens=gen_new_tokens,
                    do_sample=False,
                    num_beams=1,
                    use_cache=USE_CACHE_FOR_MEASUREMENT,  # False by default for TPU safety
                    pad_token_id=tokenizer.pad_token_id,
                    eos_token_id=tokenizer.eos_token_id,
                    return_dict_in_generate=False,
                )
            xm.mark_step()
        except Exception as e:
            # if a runtime error occurs (e.g. cache issue), fallback to safe mode (use_cache=False)
            if USE_CACHE_FOR_MEASUREMENT:
                print("Runtime error with use_cache=True; falling back to use_cache=False for this run:", repr(e))
                with torch.no_grad():
                    out = model.generate(
                        **inputs,
                        max_new_tokens=gen_new_tokens,
                        do_sample=False,
                        num_beams=1,
                        use_cache=False,
                        pad_token_id=tokenizer.pad_token_id,
                        eos_token_id=tokenizer.eos_token_id,
                        return_dict_in_generate=False,
                    )
                xm.mark_step()
            else:
                raise
        t1 = time.perf_counter()

        # compute number of output tokens (difference between output length and input length)
        out_len = int(out.shape[-1])
        generated = max(0, out_len - input_len)
        elapsed = t1 - t0
        tps = generated / elapsed if elapsed > 0 else float("inf")
        times.append(tps)
        if VERBOSE:
            print(f"Run {rep+1}/{REPEATS}: generated={generated} tokens, elapsed={elapsed:.3f}s, tps={tps:.2f}")

    mean_tps = statistics.mean(times)
    std_tps = statistics.stdev(times) if len(times) > 1 else 0.0

    results.append({
        "prompt_text": prompt,
        "prompt_actual_tokens": actual_prompt_tokens,
        "generated_tokens_requested": gen_new_tokens,
        "mean_tps": mean_tps,
        "std_tps": std_tps,
        "raw_tps": times,
    })

# Summary table
print("\n=== SUMMARY (tokens/sec measured for GENERATED tokens only) ===")
for r in results:
    print(f"Prompt (text)='{r['prompt_text']}' "
          f"(actual {r['prompt_actual_tokens']} tokens), "
          f"generated={r['generated_tokens_requested']} tokens -> "
          f"{r['mean_tps']:.2f} ± {r['std_tps']:.2f} tokens/sec (repeats={len(r['raw_tps'])})")
# Out:
# Using existing model/tokenizer/device from session.
# Model device: xla:0 dtype: torch.bfloat16
#
# === Experiment: prompt (text)='Hello, how are you'
#     actual prompt tokens=6
# Warm-up generate (short)...
# /tmp/ipython-input-3300355667.py:97: DeprecationWarning: Use torch_xla.sync instead
#   xm.mark_step()
# /tmp/ipython-input-3300355667.py:121: DeprecationWarning: Use torch_xla.sync instead
#   xm.mark_step()
# Run 1/2: generated=6 tokens, elapsed=199.303s, tps=0.03
# Run 2/2: generated=6 tokens, elapsed=1.809s, tps=3.32
#
# === Experiment: prompt (text)='Hello. What do you think about Greek philosophy?'
#     actual prompt tokens=11
# Warm-up generate (short)...
# Run 1/2: generated=11 tokens, elapsed=647.963s, tps=0.02
# Run 2/2: generated=11 tokens, elapsed=3.796s, tps=2.90
#
# === SUMMARY (tokens/sec measured for GENERATED tokens only) ===
# Prompt (text)='Hello, how are you' (actual 6 tokens), generated=6 tokens -> 1.67 ± 2.32 tokens/sec (repeats=2)
# Prompt (text)='Hello. What do you think about Greek philosophy?' (actual 11 tokens), generated=11 tokens -> 1.46 ± 2.04 tokens/sec (repeats=2)

# %%
first_param = next(model.parameters())
print("First param device:", first_param.device)
print("First param dtype:", first_param.dtype)
# compter params par dtype
from collections import Counter
dtypes = Counter([p.dtype for p in model.parameters()])
print("Param dtypes distribution:", dtypes)
# Out:
# First param device: xla:0
# First param dtype: torch.bfloat16
# Param dtypes distribution: Counter({torch.bfloat16: 884})

# %%
for n, m in model.named_modules():
     print(n, type(m).__name__)
# Out:
#  Gemma3ForConditionalGeneration
# model Gemma3Model
# model.vision_tower SiglipVisionModel
# model.vision_tower.vision_model SiglipVisionTransformer
# model.vision_tower.vision_model.embeddings SiglipVisionEmbeddings
# model.vision_tower.vision_model.embeddings.patch_embedding Conv2d
# model.vision_tower.vision_model.embeddings.position_embedding Embedding
# model.vision_tower.vision_model.encoder SiglipEncoder
# model.vision_tower.vision_model.encoder.layers ModuleList
# model.vision_tower.vision_model.encoder.layers.0 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.0.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.0.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.0.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.0.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.0.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.0.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.0.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.0.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.0.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.0.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.0.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.1 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.1.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.1.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.1.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.1.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.1.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.1.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.1.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.1.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.1.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.1.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.1.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.2 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.2.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.2.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.2.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.2.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.2.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.2.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.2.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.2.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.2.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.2.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.2.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.3 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.3.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.3.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.3.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.3.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.3.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.3.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.3.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.3.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.3.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.3.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.3.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.4 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.4.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.4.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.4.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.4.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.4.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.4.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.4.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.4.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.4.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.4.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.4.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.5 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.5.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.5.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.5.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.5.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.5.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.5.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.5.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.5.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.5.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.5.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.5.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.6 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.6.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.6.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.6.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.6.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.6.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.6.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.6.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.6.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.6.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.6.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.6.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.7 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.7.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.7.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.7.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.7.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.7.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.7.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.7.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.7.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.7.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.7.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.7.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.8 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.8.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.8.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.8.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.8.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.8.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.8.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.8.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.8.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.8.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.8.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.8.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.9 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.9.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.9.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.9.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.9.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.9.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.9.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.9.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.9.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.9.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.9.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.9.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.10 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.10.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.10.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.10.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.10.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.10.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.10.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.10.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.10.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.10.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.10.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.10.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.11 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.11.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.11.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.11.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.11.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.11.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.11.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.11.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.11.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.11.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.11.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.11.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.12 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.12.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.12.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.12.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.12.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.12.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.12.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.12.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.12.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.12.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.12.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.12.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.13 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.13.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.13.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.13.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.13.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.13.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.13.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.13.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.13.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.13.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.13.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.13.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.14 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.14.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.14.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.14.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.14.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.14.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.14.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.14.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.14.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.14.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.14.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.14.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.15 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.15.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.15.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.15.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.15.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.15.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.15.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.15.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.15.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.15.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.15.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.15.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.16 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.16.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.16.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.16.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.16.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.16.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.16.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.16.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.16.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.16.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.16.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.16.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.17 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.17.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.17.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.17.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.17.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.17.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.17.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.17.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.17.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.17.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.17.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.17.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.18 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.18.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.18.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.18.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.18.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.18.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.18.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.18.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.18.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.18.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.18.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.18.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.19 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.19.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.19.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.19.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.19.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.19.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.19.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.19.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.19.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.19.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.19.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.19.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.20 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.20.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.20.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.20.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.20.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.20.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.20.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.20.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.20.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.20.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.20.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.20.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.21 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.21.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.21.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.21.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.21.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.21.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.21.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.21.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.21.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.21.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.21.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.21.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.22 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.22.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.22.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.22.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.22.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.22.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.22.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.22.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.22.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.22.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.22.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.22.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.23 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.23.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.23.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.23.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.23.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.23.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.23.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.23.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.23.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.23.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.23.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.23.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.24 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.24.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.24.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.24.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.24.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.24.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.24.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.24.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.24.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.24.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.24.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.24.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.25 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.25.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.25.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.25.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.25.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.25.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.25.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.25.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.25.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.25.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.25.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.25.mlp.fc2 Linear
# model.vision_tower.vision_model.encoder.layers.26 SiglipEncoderLayer
# model.vision_tower.vision_model.encoder.layers.26.layer_norm1 LayerNorm
# model.vision_tower.vision_model.encoder.layers.26.self_attn SiglipAttention
# model.vision_tower.vision_model.encoder.layers.26.self_attn.k_proj Linear
# model.vision_tower.vision_model.encoder.layers.26.self_attn.v_proj Linear
# model.vision_tower.vision_model.encoder.layers.26.self_attn.q_proj Linear
# model.vision_tower.vision_model.encoder.layers.26.self_attn.out_proj Linear
# model.vision_tower.vision_model.encoder.layers.26.layer_norm2 LayerNorm
# model.vision_tower.vision_model.encoder.layers.26.mlp SiglipMLP
# model.vision_tower.vision_model.encoder.layers.26.mlp.activation_fn PytorchGELUTanh
# model.vision_tower.vision_model.encoder.layers.26.mlp.fc1 Linear
# model.vision_tower.vision_model.encoder.layers.26.mlp.fc2 Linear
# model.vision_tower.vision_model.post_layernorm LayerNorm
# model.multi_modal_projector Gemma3MultiModalProjector
# model.multi_modal_projector.mm_soft_emb_norm Gemma3RMSNorm
# model.multi_modal_projector.avg_pool AvgPool2d
# model.language_model Gemma3TextModel
# model.language_model.embed_tokens Gemma3TextScaledWordEmbedding
# model.language_model.layers ModuleList
# model.language_model.layers.0 Gemma3DecoderLayer
# model.language_model.layers.0.self_attn Gemma3Attention
# model.language_model.layers.0.self_attn.q_proj Linear
# model.language_model.layers.0.self_attn.k_proj Linear
# model.language_model.layers.0.self_attn.v_proj Linear
# model.language_model.layers.0.self_attn.o_proj Linear
# model.language_model.layers.0.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.0.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.0.mlp Gemma3MLP
# model.language_model.layers.0.mlp.gate_proj Linear
# model.language_model.layers.0.mlp.up_proj Linear
# model.language_model.layers.0.mlp.down_proj Linear
# model.language_model.layers.0.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.0.input_layernorm Gemma3RMSNorm
# model.language_model.layers.0.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.0.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.0.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.1 Gemma3DecoderLayer
# model.language_model.layers.1.self_attn Gemma3Attention
# model.language_model.layers.1.self_attn.q_proj Linear
# model.language_model.layers.1.self_attn.k_proj Linear
# model.language_model.layers.1.self_attn.v_proj Linear
# model.language_model.layers.1.self_attn.o_proj Linear
# model.language_model.layers.1.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.1.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.1.mlp Gemma3MLP
# model.language_model.layers.1.mlp.gate_proj Linear
# model.language_model.layers.1.mlp.up_proj Linear
# model.language_model.layers.1.mlp.down_proj Linear
# model.language_model.layers.1.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.1.input_layernorm Gemma3RMSNorm
# model.language_model.layers.1.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.1.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.1.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.2 Gemma3DecoderLayer
# model.language_model.layers.2.self_attn Gemma3Attention
# model.language_model.layers.2.self_attn.q_proj Linear
# model.language_model.layers.2.self_attn.k_proj Linear
# model.language_model.layers.2.self_attn.v_proj Linear
# model.language_model.layers.2.self_attn.o_proj Linear
# model.language_model.layers.2.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.2.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.2.mlp Gemma3MLP
# model.language_model.layers.2.mlp.gate_proj Linear
# model.language_model.layers.2.mlp.up_proj Linear
# model.language_model.layers.2.mlp.down_proj Linear
# model.language_model.layers.2.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.2.input_layernorm Gemma3RMSNorm
# model.language_model.layers.2.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.2.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.2.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.3 Gemma3DecoderLayer
# model.language_model.layers.3.self_attn Gemma3Attention
# model.language_model.layers.3.self_attn.q_proj Linear
# model.language_model.layers.3.self_attn.k_proj Linear
# model.language_model.layers.3.self_attn.v_proj Linear
# model.language_model.layers.3.self_attn.o_proj Linear
# model.language_model.layers.3.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.3.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.3.mlp Gemma3MLP
# model.language_model.layers.3.mlp.gate_proj Linear
# model.language_model.layers.3.mlp.up_proj Linear
# model.language_model.layers.3.mlp.down_proj Linear
# model.language_model.layers.3.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.3.input_layernorm Gemma3RMSNorm
# model.language_model.layers.3.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.3.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.3.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.4 Gemma3DecoderLayer
# model.language_model.layers.4.self_attn Gemma3Attention
# model.language_model.layers.4.self_attn.q_proj Linear
# model.language_model.layers.4.self_attn.k_proj Linear
# model.language_model.layers.4.self_attn.v_proj Linear
# model.language_model.layers.4.self_attn.o_proj Linear
# model.language_model.layers.4.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.4.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.4.mlp Gemma3MLP
# model.language_model.layers.4.mlp.gate_proj Linear
# model.language_model.layers.4.mlp.up_proj Linear
# model.language_model.layers.4.mlp.down_proj Linear
# model.language_model.layers.4.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.4.input_layernorm Gemma3RMSNorm
# model.language_model.layers.4.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.4.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.4.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.5 Gemma3DecoderLayer
# model.language_model.layers.5.self_attn Gemma3Attention
# model.language_model.layers.5.self_attn.q_proj Linear
# model.language_model.layers.5.self_attn.k_proj Linear
# model.language_model.layers.5.self_attn.v_proj Linear
# model.language_model.layers.5.self_attn.o_proj Linear
# model.language_model.layers.5.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.5.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.5.mlp Gemma3MLP
# model.language_model.layers.5.mlp.gate_proj Linear
# model.language_model.layers.5.mlp.up_proj Linear
# model.language_model.layers.5.mlp.down_proj Linear
# model.language_model.layers.5.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.5.input_layernorm Gemma3RMSNorm
# model.language_model.layers.5.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.5.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.5.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.6 Gemma3DecoderLayer
# model.language_model.layers.6.self_attn Gemma3Attention
# model.language_model.layers.6.self_attn.q_proj Linear
# model.language_model.layers.6.self_attn.k_proj Linear
# model.language_model.layers.6.self_attn.v_proj Linear
# model.language_model.layers.6.self_attn.o_proj Linear
# model.language_model.layers.6.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.6.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.6.mlp Gemma3MLP
# model.language_model.layers.6.mlp.gate_proj Linear
# model.language_model.layers.6.mlp.up_proj Linear
# model.language_model.layers.6.mlp.down_proj Linear
# model.language_model.layers.6.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.6.input_layernorm Gemma3RMSNorm
# model.language_model.layers.6.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.6.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.6.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.7 Gemma3DecoderLayer
# model.language_model.layers.7.self_attn Gemma3Attention
# model.language_model.layers.7.self_attn.q_proj Linear
# model.language_model.layers.7.self_attn.k_proj Linear
# model.language_model.layers.7.self_attn.v_proj Linear
# model.language_model.layers.7.self_attn.o_proj Linear
# model.language_model.layers.7.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.7.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.7.mlp Gemma3MLP
# model.language_model.layers.7.mlp.gate_proj Linear
# model.language_model.layers.7.mlp.up_proj Linear
# model.language_model.layers.7.mlp.down_proj Linear
# model.language_model.layers.7.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.7.input_layernorm Gemma3RMSNorm
# model.language_model.layers.7.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.7.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.7.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.8 Gemma3DecoderLayer
# model.language_model.layers.8.self_attn Gemma3Attention
# model.language_model.layers.8.self_attn.q_proj Linear
# model.language_model.layers.8.self_attn.k_proj Linear
# model.language_model.layers.8.self_attn.v_proj Linear
# model.language_model.layers.8.self_attn.o_proj Linear
# model.language_model.layers.8.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.8.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.8.mlp Gemma3MLP
# model.language_model.layers.8.mlp.gate_proj Linear
# model.language_model.layers.8.mlp.up_proj Linear
# model.language_model.layers.8.mlp.down_proj Linear
# model.language_model.layers.8.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.8.input_layernorm Gemma3RMSNorm
# model.language_model.layers.8.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.8.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.8.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.9 Gemma3DecoderLayer
# model.language_model.layers.9.self_attn Gemma3Attention
# model.language_model.layers.9.self_attn.q_proj Linear
# model.language_model.layers.9.self_attn.k_proj Linear
# model.language_model.layers.9.self_attn.v_proj Linear
# model.language_model.layers.9.self_attn.o_proj Linear
# model.language_model.layers.9.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.9.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.9.mlp Gemma3MLP
# model.language_model.layers.9.mlp.gate_proj Linear
# model.language_model.layers.9.mlp.up_proj Linear
# model.language_model.layers.9.mlp.down_proj Linear
# model.language_model.layers.9.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.9.input_layernorm Gemma3RMSNorm
# model.language_model.layers.9.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.9.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.9.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.10 Gemma3DecoderLayer
# model.language_model.layers.10.self_attn Gemma3Attention
# model.language_model.layers.10.self_attn.q_proj Linear
# model.language_model.layers.10.self_attn.k_proj Linear
# model.language_model.layers.10.self_attn.v_proj Linear
# model.language_model.layers.10.self_attn.o_proj Linear
# model.language_model.layers.10.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.10.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.10.mlp Gemma3MLP
# model.language_model.layers.10.mlp.gate_proj Linear
# model.language_model.layers.10.mlp.up_proj Linear
# model.language_model.layers.10.mlp.down_proj Linear
# model.language_model.layers.10.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.10.input_layernorm Gemma3RMSNorm
# model.language_model.layers.10.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.10.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.10.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.11 Gemma3DecoderLayer
# model.language_model.layers.11.self_attn Gemma3Attention
# model.language_model.layers.11.self_attn.q_proj Linear
# model.language_model.layers.11.self_attn.k_proj Linear
# model.language_model.layers.11.self_attn.v_proj Linear
# model.language_model.layers.11.self_attn.o_proj Linear
# model.language_model.layers.11.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.11.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.11.mlp Gemma3MLP
# model.language_model.layers.11.mlp.gate_proj Linear
# model.language_model.layers.11.mlp.up_proj Linear
# model.language_model.layers.11.mlp.down_proj Linear
# model.language_model.layers.11.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.11.input_layernorm Gemma3RMSNorm
# model.language_model.layers.11.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.11.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.11.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.12 Gemma3DecoderLayer
# model.language_model.layers.12.self_attn Gemma3Attention
# model.language_model.layers.12.self_attn.q_proj Linear
# model.language_model.layers.12.self_attn.k_proj Linear
# model.language_model.layers.12.self_attn.v_proj Linear
# model.language_model.layers.12.self_attn.o_proj Linear
# model.language_model.layers.12.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.12.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.12.mlp Gemma3MLP
# model.language_model.layers.12.mlp.gate_proj Linear
# model.language_model.layers.12.mlp.up_proj Linear
# model.language_model.layers.12.mlp.down_proj Linear
# model.language_model.layers.12.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.12.input_layernorm Gemma3RMSNorm
# model.language_model.layers.12.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.12.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.12.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.13 Gemma3DecoderLayer
# model.language_model.layers.13.self_attn Gemma3Attention
# model.language_model.layers.13.self_attn.q_proj Linear
# model.language_model.layers.13.self_attn.k_proj Linear
# model.language_model.layers.13.self_attn.v_proj Linear
# model.language_model.layers.13.self_attn.o_proj Linear
# model.language_model.layers.13.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.13.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.13.mlp Gemma3MLP
# model.language_model.layers.13.mlp.gate_proj Linear
# model.language_model.layers.13.mlp.up_proj Linear
# model.language_model.layers.13.mlp.down_proj Linear
# model.language_model.layers.13.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.13.input_layernorm Gemma3RMSNorm
# model.language_model.layers.13.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.13.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.13.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.14 Gemma3DecoderLayer
# model.language_model.layers.14.self_attn Gemma3Attention
# model.language_model.layers.14.self_attn.q_proj Linear
# model.language_model.layers.14.self_attn.k_proj Linear
# model.language_model.layers.14.self_attn.v_proj Linear
# model.language_model.layers.14.self_attn.o_proj Linear
# model.language_model.layers.14.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.14.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.14.mlp Gemma3MLP
# model.language_model.layers.14.mlp.gate_proj Linear
# model.language_model.layers.14.mlp.up_proj Linear
# model.language_model.layers.14.mlp.down_proj Linear
# model.language_model.layers.14.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.14.input_layernorm Gemma3RMSNorm
# model.language_model.layers.14.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.14.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.14.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.15 Gemma3DecoderLayer
# model.language_model.layers.15.self_attn Gemma3Attention
# model.language_model.layers.15.self_attn.q_proj Linear
# model.language_model.layers.15.self_attn.k_proj Linear
# model.language_model.layers.15.self_attn.v_proj Linear
# model.language_model.layers.15.self_attn.o_proj Linear
# model.language_model.layers.15.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.15.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.15.mlp Gemma3MLP
# model.language_model.layers.15.mlp.gate_proj Linear
# model.language_model.layers.15.mlp.up_proj Linear
# model.language_model.layers.15.mlp.down_proj Linear
# model.language_model.layers.15.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.15.input_layernorm Gemma3RMSNorm
# model.language_model.layers.15.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.15.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.15.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.16 Gemma3DecoderLayer
# model.language_model.layers.16.self_attn Gemma3Attention
# model.language_model.layers.16.self_attn.q_proj Linear
# model.language_model.layers.16.self_attn.k_proj Linear
# model.language_model.layers.16.self_attn.v_proj Linear
# model.language_model.layers.16.self_attn.o_proj Linear
# model.language_model.layers.16.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.16.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.16.mlp Gemma3MLP
# model.language_model.layers.16.mlp.gate_proj Linear
# model.language_model.layers.16.mlp.up_proj Linear
# model.language_model.layers.16.mlp.down_proj Linear
# model.language_model.layers.16.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.16.input_layernorm Gemma3RMSNorm
# model.language_model.layers.16.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.16.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.16.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.17 Gemma3DecoderLayer
# model.language_model.layers.17.self_attn Gemma3Attention
# model.language_model.layers.17.self_attn.q_proj Linear
# model.language_model.layers.17.self_attn.k_proj Linear
# model.language_model.layers.17.self_attn.v_proj Linear
# model.language_model.layers.17.self_attn.o_proj Linear
# model.language_model.layers.17.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.17.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.17.mlp Gemma3MLP
# model.language_model.layers.17.mlp.gate_proj Linear
# model.language_model.layers.17.mlp.up_proj Linear
# model.language_model.layers.17.mlp.down_proj Linear
# model.language_model.layers.17.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.17.input_layernorm Gemma3RMSNorm
# model.language_model.layers.17.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.17.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.17.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.18 Gemma3DecoderLayer
# model.language_model.layers.18.self_attn Gemma3Attention
# model.language_model.layers.18.self_attn.q_proj Linear
# model.language_model.layers.18.self_attn.k_proj Linear
# model.language_model.layers.18.self_attn.v_proj Linear
# model.language_model.layers.18.self_attn.o_proj Linear
# model.language_model.layers.18.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.18.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.18.mlp Gemma3MLP
# model.language_model.layers.18.mlp.gate_proj Linear
# model.language_model.layers.18.mlp.up_proj Linear
# model.language_model.layers.18.mlp.down_proj Linear
# model.language_model.layers.18.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.18.input_layernorm Gemma3RMSNorm
# model.language_model.layers.18.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.18.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.18.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.19 Gemma3DecoderLayer
# model.language_model.layers.19.self_attn Gemma3Attention
# model.language_model.layers.19.self_attn.q_proj Linear
# model.language_model.layers.19.self_attn.k_proj Linear
# model.language_model.layers.19.self_attn.v_proj Linear
# model.language_model.layers.19.self_attn.o_proj Linear
# model.language_model.layers.19.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.19.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.19.mlp Gemma3MLP
# model.language_model.layers.19.mlp.gate_proj Linear
# model.language_model.layers.19.mlp.up_proj Linear
# model.language_model.layers.19.mlp.down_proj Linear
# model.language_model.layers.19.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.19.input_layernorm Gemma3RMSNorm
# model.language_model.layers.19.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.19.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.19.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.20 Gemma3DecoderLayer
# model.language_model.layers.20.self_attn Gemma3Attention
# model.language_model.layers.20.self_attn.q_proj Linear
# model.language_model.layers.20.self_attn.k_proj Linear
# model.language_model.layers.20.self_attn.v_proj Linear
# model.language_model.layers.20.self_attn.o_proj Linear
# model.language_model.layers.20.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.20.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.20.mlp Gemma3MLP
# model.language_model.layers.20.mlp.gate_proj Linear
# model.language_model.layers.20.mlp.up_proj Linear
# model.language_model.layers.20.mlp.down_proj Linear
# model.language_model.layers.20.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.20.input_layernorm Gemma3RMSNorm
# model.language_model.layers.20.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.20.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.20.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.21 Gemma3DecoderLayer
# model.language_model.layers.21.self_attn Gemma3Attention
# model.language_model.layers.21.self_attn.q_proj Linear
# model.language_model.layers.21.self_attn.k_proj Linear
# model.language_model.layers.21.self_attn.v_proj Linear
# model.language_model.layers.21.self_attn.o_proj Linear
# model.language_model.layers.21.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.21.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.21.mlp Gemma3MLP
# model.language_model.layers.21.mlp.gate_proj Linear
# model.language_model.layers.21.mlp.up_proj Linear
# model.language_model.layers.21.mlp.down_proj Linear
# model.language_model.layers.21.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.21.input_layernorm Gemma3RMSNorm
# model.language_model.layers.21.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.21.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.21.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.22 Gemma3DecoderLayer
# model.language_model.layers.22.self_attn Gemma3Attention
# model.language_model.layers.22.self_attn.q_proj Linear
# model.language_model.layers.22.self_attn.k_proj Linear
# model.language_model.layers.22.self_attn.v_proj Linear
# model.language_model.layers.22.self_attn.o_proj Linear
# model.language_model.layers.22.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.22.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.22.mlp Gemma3MLP
# model.language_model.layers.22.mlp.gate_proj Linear
# model.language_model.layers.22.mlp.up_proj Linear
# model.language_model.layers.22.mlp.down_proj Linear
# model.language_model.layers.22.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.22.input_layernorm Gemma3RMSNorm
# model.language_model.layers.22.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.22.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.22.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.23 Gemma3DecoderLayer
# model.language_model.layers.23.self_attn Gemma3Attention
# model.language_model.layers.23.self_attn.q_proj Linear
# model.language_model.layers.23.self_attn.k_proj Linear
# model.language_model.layers.23.self_attn.v_proj Linear
# model.language_model.layers.23.self_attn.o_proj Linear
# model.language_model.layers.23.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.23.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.23.mlp Gemma3MLP
# model.language_model.layers.23.mlp.gate_proj Linear
# model.language_model.layers.23.mlp.up_proj Linear
# model.language_model.layers.23.mlp.down_proj Linear
# model.language_model.layers.23.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.23.input_layernorm Gemma3RMSNorm
# model.language_model.layers.23.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.23.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.23.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.24 Gemma3DecoderLayer
# model.language_model.layers.24.self_attn Gemma3Attention
# model.language_model.layers.24.self_attn.q_proj Linear
# model.language_model.layers.24.self_attn.k_proj Linear
# model.language_model.layers.24.self_attn.v_proj Linear
# model.language_model.layers.24.self_attn.o_proj Linear
# model.language_model.layers.24.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.24.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.24.mlp Gemma3MLP
# model.language_model.layers.24.mlp.gate_proj Linear
# model.language_model.layers.24.mlp.up_proj Linear
# model.language_model.layers.24.mlp.down_proj Linear
# model.language_model.layers.24.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.24.input_layernorm Gemma3RMSNorm
# model.language_model.layers.24.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.24.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.24.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.25 Gemma3DecoderLayer
# model.language_model.layers.25.self_attn Gemma3Attention
# model.language_model.layers.25.self_attn.q_proj Linear
# model.language_model.layers.25.self_attn.k_proj Linear
# model.language_model.layers.25.self_attn.v_proj Linear
# model.language_model.layers.25.self_attn.o_proj Linear
# model.language_model.layers.25.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.25.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.25.mlp Gemma3MLP
# model.language_model.layers.25.mlp.gate_proj Linear
# model.language_model.layers.25.mlp.up_proj Linear
# model.language_model.layers.25.mlp.down_proj Linear
# model.language_model.layers.25.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.25.input_layernorm Gemma3RMSNorm
# model.language_model.layers.25.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.25.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.25.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.26 Gemma3DecoderLayer
# model.language_model.layers.26.self_attn Gemma3Attention
# model.language_model.layers.26.self_attn.q_proj Linear
# model.language_model.layers.26.self_attn.k_proj Linear
# model.language_model.layers.26.self_attn.v_proj Linear
# model.language_model.layers.26.self_attn.o_proj Linear
# model.language_model.layers.26.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.26.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.26.mlp Gemma3MLP
# model.language_model.layers.26.mlp.gate_proj Linear
# model.language_model.layers.26.mlp.up_proj Linear
# model.language_model.layers.26.mlp.down_proj Linear
# model.language_model.layers.26.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.26.input_layernorm Gemma3RMSNorm
# model.language_model.layers.26.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.26.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.26.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.27 Gemma3DecoderLayer
# model.language_model.layers.27.self_attn Gemma3Attention
# model.language_model.layers.27.self_attn.q_proj Linear
# model.language_model.layers.27.self_attn.k_proj Linear
# model.language_model.layers.27.self_attn.v_proj Linear
# model.language_model.layers.27.self_attn.o_proj Linear
# model.language_model.layers.27.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.27.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.27.mlp Gemma3MLP
# model.language_model.layers.27.mlp.gate_proj Linear
# model.language_model.layers.27.mlp.up_proj Linear
# model.language_model.layers.27.mlp.down_proj Linear
# model.language_model.layers.27.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.27.input_layernorm Gemma3RMSNorm
# model.language_model.layers.27.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.27.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.27.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.28 Gemma3DecoderLayer
# model.language_model.layers.28.self_attn Gemma3Attention
# model.language_model.layers.28.self_attn.q_proj Linear
# model.language_model.layers.28.self_attn.k_proj Linear
# model.language_model.layers.28.self_attn.v_proj Linear
# model.language_model.layers.28.self_attn.o_proj Linear
# model.language_model.layers.28.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.28.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.28.mlp Gemma3MLP
# model.language_model.layers.28.mlp.gate_proj Linear
# model.language_model.layers.28.mlp.up_proj Linear
# model.language_model.layers.28.mlp.down_proj Linear
# model.language_model.layers.28.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.28.input_layernorm Gemma3RMSNorm
# model.language_model.layers.28.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.28.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.28.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.29 Gemma3DecoderLayer
# model.language_model.layers.29.self_attn Gemma3Attention
# model.language_model.layers.29.self_attn.q_proj Linear
# model.language_model.layers.29.self_attn.k_proj Linear
# model.language_model.layers.29.self_attn.v_proj Linear
# model.language_model.layers.29.self_attn.o_proj Linear
# model.language_model.layers.29.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.29.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.29.mlp Gemma3MLP
# model.language_model.layers.29.mlp.gate_proj Linear
# model.language_model.layers.29.mlp.up_proj Linear
# model.language_model.layers.29.mlp.down_proj Linear
# model.language_model.layers.29.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.29.input_layernorm Gemma3RMSNorm
# model.language_model.layers.29.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.29.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.29.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.30 Gemma3DecoderLayer
# model.language_model.layers.30.self_attn Gemma3Attention
# model.language_model.layers.30.self_attn.q_proj Linear
# model.language_model.layers.30.self_attn.k_proj Linear
# model.language_model.layers.30.self_attn.v_proj Linear
# model.language_model.layers.30.self_attn.o_proj Linear
# model.language_model.layers.30.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.30.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.30.mlp Gemma3MLP
# model.language_model.layers.30.mlp.gate_proj Linear
# model.language_model.layers.30.mlp.up_proj Linear
# model.language_model.layers.30.mlp.down_proj Linear
# model.language_model.layers.30.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.30.input_layernorm Gemma3RMSNorm
# model.language_model.layers.30.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.30.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.30.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.31 Gemma3DecoderLayer
# model.language_model.layers.31.self_attn Gemma3Attention
# model.language_model.layers.31.self_attn.q_proj Linear
# model.language_model.layers.31.self_attn.k_proj Linear
# model.language_model.layers.31.self_attn.v_proj Linear
# model.language_model.layers.31.self_attn.o_proj Linear
# model.language_model.layers.31.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.31.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.31.mlp Gemma3MLP
# model.language_model.layers.31.mlp.gate_proj Linear
# model.language_model.layers.31.mlp.up_proj Linear
# model.language_model.layers.31.mlp.down_proj Linear
# model.language_model.layers.31.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.31.input_layernorm Gemma3RMSNorm
# model.language_model.layers.31.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.31.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.31.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.32 Gemma3DecoderLayer
# model.language_model.layers.32.self_attn Gemma3Attention
# model.language_model.layers.32.self_attn.q_proj Linear
# model.language_model.layers.32.self_attn.k_proj Linear
# model.language_model.layers.32.self_attn.v_proj Linear
# model.language_model.layers.32.self_attn.o_proj Linear
# model.language_model.layers.32.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.32.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.32.mlp Gemma3MLP
# model.language_model.layers.32.mlp.gate_proj Linear
# model.language_model.layers.32.mlp.up_proj Linear
# model.language_model.layers.32.mlp.down_proj Linear
# model.language_model.layers.32.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.32.input_layernorm Gemma3RMSNorm
# model.language_model.layers.32.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.32.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.32.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.33 Gemma3DecoderLayer
# model.language_model.layers.33.self_attn Gemma3Attention
# model.language_model.layers.33.self_attn.q_proj Linear
# model.language_model.layers.33.self_attn.k_proj Linear
# model.language_model.layers.33.self_attn.v_proj Linear
# model.language_model.layers.33.self_attn.o_proj Linear
# model.language_model.layers.33.self_attn.q_norm Gemma3RMSNorm
# model.language_model.layers.33.self_attn.k_norm Gemma3RMSNorm
# model.language_model.layers.33.mlp Gemma3MLP
# model.language_model.layers.33.mlp.gate_proj Linear
# model.language_model.layers.33.mlp.up_proj Linear
# model.language_model.layers.33.mlp.down_proj Linear
# model.language_model.layers.33.mlp.act_fn PytorchGELUTanh
# model.language_model.layers.33.input_layernorm Gemma3RMSNorm
# model.language_model.layers.33.post_attention_layernorm Gemma3RMSNorm
# model.language_model.layers.33.pre_feedforward_layernorm Gemma3RMSNorm
# model.language_model.layers.33.post_feedforward_layernorm Gemma3RMSNorm
# model.language_model.norm Gemma3RMSNorm
# model.language_model.rotary_emb Gemma3RotaryEmbedding
# model.language_model.rotary_emb_local Gemma3RotaryEmbedding
# lm_head Linear
